# %%
# %pip install sacremoses==0.0.53
# %pip install datasets
# %pip install transformers
# %pip install torch torchvision torchaudio
# %pip install "transformers[sentencepiece]"
# Out:
# Collecting sacremoses==0.0.53
#   Using cached sacremoses-0.0.53-py3-none-any.whl
# Collecting regex (from sacremoses==0.0.53)
#   Using cached regex-2023.12.25-cp310-cp310-win_amd64.whl.metadata (41 kB)
# Requirement already satisfied: six in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from sacremoses==0.0.53) (1.16.0)
# Collecting click (from sacremoses==0.0.53)
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting joblib (from sacremoses==0.0.53)
#   Using cached joblib-1.3.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting tqdm (from sacremoses==0.0.53)
#   Using cached tqdm-4.66.2-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: colorama in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from click->sacremoses==0.0.53) (0.4.6)
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Using cached joblib-1.3.2-py3-none-any.whl (302 kB)
# Using cached regex-2023.12.25-cp310-cp310-win_amd64.whl (269 kB)
# Using cached tqdm-4.66.2-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, regex, joblib, click, sacremoses
# Successfully installed click-8.1.7 joblib-1.3.2 regex-2023.12.25 sacremoses-0.0.53 tqdm-4.66.2
# Note: you may need to restart the kernel to use updated packages.
# Collecting datasets
#   Downloading datasets-2.17.0-py3-none-any.whl.metadata (20 kB)
# Collecting filelock (from datasets)
#   Using cached filelock-3.13.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting numpy>=1.17 (from datasets)
#   Using cached numpy-1.26.4-cp310-cp310-win_amd64.whl.metadata (61 kB)
# Collecting pyarrow>=12.0.0 (from datasets)
#   Using cached pyarrow-15.0.0-cp310-cp310-win_amd64.whl.metadata (3.1 kB)
# Collecting pyarrow-hotfix (from datasets)
#   Downloading pyarrow_hotfix-0.6-py3-none-any.whl.metadata (3.6 kB)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Collecting pandas (from datasets)
#   Using cached pandas-2.2.0-cp310-cp310-win_amd64.whl.metadata (19 kB)
# Collecting requests>=2.19.0 (from datasets)
#   Using cached requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: tqdm>=4.62.1 in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from datasets) (4.66.2)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.4.1-cp310-cp310-win_amd64.whl.metadata (12 kB)
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2023.10.0,>=2023.1.0 (from fsspec[http]<=2023.10.0,>=2023.1.0->datasets)
#   Downloading fsspec-2023.10.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting aiohttp (from datasets)
#   Using cached aiohttp-3.9.3-cp310-cp310-win_amd64.whl.metadata (7.6 kB)
# Collecting huggingface-hub>=0.19.4 (from datasets)
#   Using cached huggingface_hub-0.20.3-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: packaging in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from datasets) (23.2)
# Collecting pyyaml>=5.1 (from datasets)
#   Using cached PyYAML-6.0.1-cp310-cp310-win_amd64.whl.metadata (2.1 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp->datasets)
#   Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting attrs>=17.3.0 (from aiohttp->datasets)
#   Using cached attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp->datasets)
#   Using cached frozenlist-1.4.1-cp310-cp310-win_amd64.whl.metadata (12 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp->datasets)
#   Using cached multidict-6.0.5-cp310-cp310-win_amd64.whl.metadata (4.3 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp->datasets)
#   Using cached yarl-1.9.4-cp310-cp310-win_amd64.whl.metadata (32 kB)
# Collecting async-timeout<5.0,>=4.0 (from aiohttp->datasets)
#   Using cached async_timeout-4.0.3-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from huggingface-hub>=0.19.4->datasets) (4.9.0)
# Collecting charset-normalizer<4,>=2 (from requests>=2.19.0->datasets)
#   Using cached charset_normalizer-3.3.2-cp310-cp310-win_amd64.whl.metadata (34 kB)
# Collecting idna<4,>=2.5 (from requests>=2.19.0->datasets)
#   Using cached idna-3.6-py3-none-any.whl.metadata (9.9 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.19.0->datasets)
#   Using cached urllib3-2.2.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting certifi>=2017.4.17 (from requests>=2.19.0->datasets)
#   Using cached certifi-2024.2.2-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: colorama in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from tqdm>=4.62.1->datasets) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from pandas->datasets) (2.8.2)
# Collecting pytz>=2020.1 (from pandas->datasets)
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas->datasets)
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Downloading datasets-2.17.0-py3-none-any.whl (536 kB)
#    ---------------------------------------- 0.0/536.6 kB ? eta -:--:--
#    -- ------------------------------------ 41.0/536.6 kB 653.6 kB/s eta 0:00:01
#    --------- ------------------------------ 122.9/536.6 kB 1.4 MB/s eta 0:00:01
#    ---------------------- ----------------- 307.2/536.6 kB 2.4 MB/s eta 0:00:01
#    ---------------------------------------  532.5/536.6 kB 3.0 MB/s eta 0:00:01
#    ---------------------------------------- 536.6/536.6 kB 2.8 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ---------------------------------------- 0.0/116.3 kB ? eta -:--:--
#    ---------------------------------------- 116.3/116.3 kB 6.6 MB/s eta 0:00:00
# Downloading fsspec-2023.10.0-py3-none-any.whl (166 kB)
#    ---------------------------------------- 0.0/166.4 kB ? eta -:--:--
#    --------------------------------------- 166.4/166.4 kB 10.4 MB/s eta 0:00:00
# Using cached aiohttp-3.9.3-cp310-cp310-win_amd64.whl (365 kB)
# Using cached huggingface_hub-0.20.3-py3-none-any.whl (330 kB)
# Using cached numpy-1.26.4-cp310-cp310-win_amd64.whl (15.8 MB)
# Using cached pyarrow-15.0.0-cp310-cp310-win_amd64.whl (24.8 MB)
# Using cached PyYAML-6.0.1-cp310-cp310-win_amd64.whl (145 kB)
# Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Using cached filelock-3.13.1-py3-none-any.whl (11 kB)
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ---------------------------------------- 0.0/134.8 kB ? eta -:--:--
#    ---------------------------------------- 134.8/134.8 kB ? eta 0:00:00
# Using cached pandas-2.2.0-cp310-cp310-win_amd64.whl (11.6 MB)
# Downloading pyarrow_hotfix-0.6-py3-none-any.whl (7.9 kB)
# Downloading xxhash-3.4.1-cp310-cp310-win_amd64.whl (29 kB)
# Using cached async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Using cached attrs-23.2.0-py3-none-any.whl (60 kB)
# Using cached certifi-2024.2.2-py3-none-any.whl (163 kB)
# Using cached charset_normalizer-3.3.2-cp310-cp310-win_amd64.whl (100 kB)
# Using cached frozenlist-1.4.1-cp310-cp310-win_amd64.whl (50 kB)
# Using cached idna-3.6-py3-none-any.whl (61 kB)
# Using cached multidict-6.0.5-cp310-cp310-win_amd64.whl (28 kB)
# Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Using cached urllib3-2.2.0-py3-none-any.whl (120 kB)
# Using cached yarl-1.9.4-cp310-cp310-win_amd64.whl (76 kB)
# Installing collected packages: pytz, xxhash, urllib3, tzdata, pyyaml, pyarrow-hotfix, numpy, multidict, idna, fsspec, frozenlist, filelock, dill, charset-normalizer, certifi, attrs, async-timeout, yarl, requests, pyarrow, pandas, multiprocess, aiosignal, huggingface-hub, aiohttp, datasets
# Successfully installed aiohttp-3.9.3 aiosignal-1.3.1 async-timeout-4.0.3 attrs-23.2.0 certifi-2024.2.2 charset-normalizer-3.3.2 datasets-2.17.0 dill-0.3.8 filelock-3.13.1 frozenlist-1.4.1 fsspec-2023.10.0 huggingface-hub-0.20.3 idna-3.6 multidict-6.0.5 multiprocess-0.70.16 numpy-1.26.4 pandas-2.2.0 pyarrow-15.0.0 pyarrow-hotfix-0.6 pytz-2024.1 pyyaml-6.0.1 requests-2.31.0 tzdata-2024.1 urllib3-2.2.0 xxhash-3.4.1 yarl-1.9.4
# Note: you may need to restart the kernel to use updated packages.
# Collecting transformersNote: you may need to restart the kernel to use updated packages.
#
#   Using cached transformers-4.37.2-py3-none-any.whl.metadata (129 kB)
# Requirement already satisfied: filelock in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from transformers) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from transformers) (2.31.0)
# Collecting tokenizers<0.19,>=0.14 (from transformers)
#   Using cached tokenizers-0.15.2-cp310-none-win_amd64.whl.metadata (6.8 kB)
# Collecting safetensors>=0.4.1 (from transformers)
#   Using cached safetensors-0.4.2-cp310-none-win_amd64.whl.metadata (3.9 kB)
# Requirement already satisfied: tqdm>=4.27 in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from transformers) (4.66.2)
# Requirement already satisfied: fsspec>=2023.5.0 in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2023.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.9.0)
# Requirement already satisfied: colorama in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from requests->transformers) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from requests->transformers) (2024.2.2)
# Using cached transformers-4.37.2-py3-none-any.whl (8.4 MB)
# Using cached safetensors-0.4.2-cp310-none-win_amd64.whl (269 kB)
# Using cached tokenizers-0.15.2-cp310-none-win_amd64.whl (2.2 MB)
# Installing collected packages: safetensors, tokenizers, transformers
# Successfully installed safetensors-0.4.2 tokenizers-0.15.2 transformers-4.37.2
# Collecting torch
#   Downloading torch-2.2.0-cp310-cp310-win_amd64.whl.metadata (26 kB)
# Collecting torchvision
#   Downloading torchvision-0.17.0-cp310-cp310-win_amd64.whl.metadata (6.6 kB)
# Collecting torchaudio
#   Downloading torchaudio-2.2.0-cp310-cp310-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: filelock in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from torch) (4.9.0)
# Collecting sympy (from torch)
#   Using cached sympy-1.12-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch)
#   Using cached networkx-3.2.1-py3-none-any.whl.metadata (5.2 kB)
# Collecting jinja2 (from torch)
#   Using cached Jinja2-3.1.3-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: fsspec in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from torch) (2023.10.0)
# Requirement already satisfied: numpy in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: requests in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from torchvision) (2.31.0)
# Collecting pillow!=8.3.*,>=5.3.0 (from torchvision)
#   Using cached pillow-10.2.0-cp310-cp310-win_amd64.whl.metadata (9.9 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch)
#   Using cached MarkupSafe-2.1.5-cp310-cp310-win_amd64.whl.metadata (3.1 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from requests->torchvision) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from requests->torchvision) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from requests->torchvision) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from requests->torchvision) (2024.2.2)
# Collecting mpmath>=0.19 (from sympy->torch)
#   Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Downloading torch-2.2.0-cp310-cp310-win_amd64.whl (198.6 MB)
#    ---------------------------------------- 0.0/198.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/198.6 MB 991.0 kB/s eta 0:03:21
#    ---------------------------------------- 0.1/198.6 MB 919.0 kB/s eta 0:03:36
#    ---------------------------------------- 0.2/198.6 MB 1.4 MB/s eta 0:02:21
#    ---------------------------------------- 0.3/198.6 MB 2.0 MB/s eta 0:01:41
#    ---------------------------------------- 0.5/198.6 MB 2.3 MB/s eta 0:01:27
#    ---------------------------------------- 0.7/198.6 MB 2.5 MB/s eta 0:01:19
#    ---------------------------------------- 1.1/198.6 MB 3.6 MB/s eta 0:00:55
#    ---------------------------------------- 1.9/198.6 MB 5.2 MB/s eta 0:00:39
#     --------------------------------------- 3.0/198.6 MB 7.2 MB/s eta 0:00:28
#     --------------------------------------- 4.6/198.6 MB 9.8 MB/s eta 0:00:20
198.6 MB 18.7 MB/s eta 0:00:04
#    ------------------------- ------------- 128.7/198.6 MB 21.1 MB/s eta 0:00:04
#    ------------------------- ------------- 130.2/198.6 MB 22.6 MB/s eta 0:00:04
#    ------------------------- ------------- 131.3/198.6 MB 23.4 MB/s eta 0:00:03
#    ------------------------- ------------- 132.3/198.6 MB 24.2 MB/s eta 0:00:03
#    -------------------------- ------------ 133.3/198.6 MB 25.1 MB/s eta 0:00:03
#    -------------------------- ------------ 134.3/198.6 MB 26.2 MB/s eta 0:00:03
#    -------------------------- ------------ 135.2/198.6 MB 27.3 MB/s eta 0:00:03
#    -------------------------- ------------ 136.1/198.6 MB 26.2 MB/s eta 0:00:03
#    -------------------------- ------------ 137.0/198.6 MB 24.2 MB/s eta 0:00:03
#    --------------------------- ----------- 137.9/198.6 MB 22.6 MB/s eta 0:00:03
#    --------------------------- ----------- 138.6/198.6 MB 20.5 MB/s eta 0:00:03
#    --------------------------- ----------- 139.5/198.6 MB 19.8 MB/s eta 0:00:03
#    --------------------------- ----------- 140.2/198.6 MB 19.3 MB/s eta 0:00:04
#    --------------------------- ----------- 141.1/198.6 MB 18.2 MB/s eta 0:00:04
#    --------------------------- ----------- 141.8/198.6 MB 17.7 MB/s eta 0:00:04
#    ---------------------------- ---------- 143.8/198.6 MB 19.3 MB/s eta 0:00:03
#    ---------------------------- ---------- 146.7/198.6 MB 24.2 MB/s eta 0:00:03
#    ----------------------------- --------- 149.3/198.6 MB 31.1 MB/s eta 0:00:02
#    ----------------------------- --------- 150.8/198.6 MB 38.5 MB/s eta 0:00:02
#    ------------------------------ -------- 153.4/198.6 MB 46.9 MB/s eta 0:00:01
#    ------------------------------ -------- 155.9/198.6 MB 46.7 MB/s eta 0:00:01
#    ------------------------------- ------- 158.2/198.6 MB 46.7 MB/s eta 0:00:01
#    ------------------------------- ------- 159.9/198.6 MB 46.7 MB/s eta 0:00:01
#    ------------------------------- ------- 162.5/198.6 MB 46.7 MB/s eta 0:00:01
#    -------------------------------- ------ 165.4/198.6 MB 46.9 MB/s eta 0:00:01
#    -------------------------------- ------ 167.5/198.6 MB 46.7 MB/s eta 0:00:01
#    --------------------------------- ----- 169.5/198.6 MB 46.7 MB/s eta 0:00:01
#    --------------------------------- ----- 171.4/198.6 MB 50.4 MB/s eta 0:00:01
#    ---------------------------------- ---- 173.9/198.6 MB 50.4 MB/s eta 0:00:01
#    ---------------------------------- ---- 175.9/198.6 MB 50.4 MB/s eta 0:00:01
#    ---------------------------------- ---- 178.2/198.6 MB 46.7 MB/s eta 0:00:01
#    ----------------------------------- --- 179.5/198.6 MB 40.9 MB/s eta 0:00:01
#    ----------------------------------- --- 180.7/198.6 MB 38.6 MB/s eta 0:00:01
#    ----------------------------------- --- 182.0/198.6 MB 34.4 MB/s eta 0:00:01
#    ----------------------------------- --- 183.2/198.6 MB 31.2 MB/s eta 0:00:01
#    ------------------------------------ -- 184.2/198.6 MB 29.7 MB/s eta 0:00:01
#    ------------------------------------ -- 185.2/198.6 MB 27.3 MB/s eta 0:00:01
#    ------------------------------------ -- 186.0/198.6 MB 25.2 MB/s eta 0:00:01
#    ------------------------------------ -- 187.0/198.6 MB 23.4 MB/s eta 0:00:01
#    ------------------------------------ -- 187.8/198.6 MB 21.8 MB/s eta 0:00:01
#    ------------------------------------- - 188.6/198.6 MB 21.1 MB/s eta 0:00:01
#    ------------------------------------- - 189.4/198.6 MB 19.9 MB/s eta 0:00:01
#    ------------------------------------- - 190.2/198.6 MB 19.9 MB/s eta 0:00:01
#    ------------------------------------- - 190.9/198.6 MB 18.2 MB/s eta 0:00:01
#    ------------------------------------- - 191.6/198.6 MB 17.7 MB/s eta 0:00:01
#    ------------------------------------- - 192.1/198.6 MB 17.2 MB/s eta 0:00:01
#    --------------------------------------  195.0/198.6 MB 20.5 MB/s eta 0:00:01
#    --------------------------------------  197.7/198.6 MB 25.2 MB/s eta 0:00:01
#    --------------------------------------  198.6/198.6 MB 27.3 MB/s eta 0:00:01
#    --------------------------------------  198.6/198.6 MB 27.3 MB/s eta 0:00:01
#    --------------------------------------  198.6/198.6 MB 27.3 MB/s eta 0:00:01
#    --------------------------------------  198.6/198.6 MB 27.3 MB/s eta 0:00:01
#    --------------------------------------  198.6/198.6 MB 27.3 MB/s eta 0:00:01
#    --------------------------------------  198.6/198.6 MB 27.3 MB/s eta 0:00:01
#    --------------------------------------  198.6/198.6 MB 27.3 MB/s eta 0:00:01
#    --------------------------------------  198.6/198.6 MB 27.3 MB/s eta 0:00:01
#    --------------------------------------  198.6/198.6 MB 27.3 MB/s eta 0:00:01
#    --------------------------------------  198.6/198.6 MB 27.3 MB/s eta 0:00:01
#    --------------------------------------  198.6/198.6 MB 27.3 MB/s eta 0:00:01
#    --------------------------------------  198.6/198.6 MB 27.3 MB/s eta 0:00:01
#    --------------------------------------  198.6/198.6 MB 27.3 MB/s eta 0:00:01
#    --------------------------------------  198.6/198.6 MB 27.3 MB/s eta 0:00:01
#    --------------------------------------  198.6/198.6 MB 27.3 MB/s eta 0:00:01
#    --------------------------------------  198.6/198.6 MB 27.3 MB/s eta 0:00:01
#    --------------------------------------  198.6/198.6 MB 27.3 MB/s eta 0:00:01
#    --------------------------------------  198.6/198.6 MB 27.3 MB/s eta 0:00:01
#    --------------------------------------  198.6/198.6 MB 27.3 MB/s eta 0:00:01
#    --------------------------------------  198.6/198.6 MB 27.3 MB/s eta 0:00:01
#    --------------------------------------  198.6/198.6 MB 27.3 MB/s eta 0:00:01
#    --------------------------------------  198.6/198.6 MB 27.3 MB/s eta 0:00:01
#    --------------------------------------  198.6/198.6 MB 27.3 MB/s eta 0:00:01
#    --------------------------------------  198.6/198.6 MB 27.3 MB/s eta 0:00:01
#    ---------------------------------------- 198.6/198.6 MB 6.7 MB/s eta 0:00:00
# Downloading torchvision-0.17.0-cp310-cp310-win_amd64.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------  1.2/1.2 MB 71.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.2/1.2 MB 24.6 MB/s eta 0:00:00
# Downloading torchaudio-2.2.0-cp310-cp310-win_amd64.whl (2.4 MB)
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ------------------------------ --------- 1.8/2.4 MB 38.5 MB/s eta 0:00:01
#    ---------------------------------------  2.4/2.4 MB 37.8 MB/s eta 0:00:01
#    ---------------------------------------- 2.4/2.4 MB 21.6 MB/s eta 0:00:00
# Using cached pillow-10.2.0-cp310-cp310-win_amd64.whl (2.6 MB)
# Using cached Jinja2-3.1.3-py3-none-any.whl (133 kB)
# Using cached networkx-3.2.1-py3-none-any.whl (1.6 MB)
# Using cached sympy-1.12-py3-none-any.whl (5.7 MB)
# Using cached MarkupSafe-2.1.5-cp310-cp310-win_amd64.whl (17 kB)
# Installing collected packages: mpmath, sympy, pillow, networkx, MarkupSafe, jinja2, torch, torchvision, torchaudio
# Successfully installed MarkupSafe-2.1.5 jinja2-3.1.3 mpmath-1.3.0 networkx-3.2.1 pillow-10.2.0 sympy-1.12 torch-2.2.0 torchaudio-2.2.0 torchvision-0.17.0
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: transformers[sentencepiece] in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (4.37.2)
# Requirement already satisfied: filelock in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from transformers[sentencepiece]) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from transformers[sentencepiece]) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from transformers[sentencepiece]) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from transformers[sentencepiece]) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from transformers[sentencepiece]) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from transformers[sentencepiece]) (2023.12.25)
# Requirement already satisfied: requests in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from transformers[sentencepiece]) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from transformers[sentencepiece]) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from transformers[sentencepiece]) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from transformers[sentencepiece]) (4.66.2)
# Collecting sentencepiece!=0.1.92,>=0.1.91 (from transformers[sentencepiece])
#   Using cached sentencepiece-0.1.99-cp310-cp310-win_amd64.whl.metadata (8.3 kB)
# Collecting protobuf (from transformers[sentencepiece])
#   Using cached protobuf-4.25.2-cp310-abi3-win_amd64.whl.metadata (541 bytes)
# Requirement already satisfied: fsspec>=2023.5.0 in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from huggingface-hub<1.0,>=0.19.3->transformers[sentencepiece]) (2023.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from huggingface-hub<1.0,>=0.19.3->transformers[sentencepiece]) (4.9.0)
# Requirement already satisfied: colorama in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from tqdm>=4.27->transformers[sentencepiece]) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from requests->transformers[sentencepiece]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from requests->transformers[sentencepiece]) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from requests->transformers[sentencepiece]) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from requests->transformers[sentencepiece]) (2024.2.2)
# Using cached sentencepiece-0.1.99-cp310-cp310-win_amd64.whl (977 kB)
# Using cached protobuf-4.25.2-cp310-abi3-win_amd64.whl (413 kB)
# Installing collected packages: sentencepiece, protobuf
# Successfully installed protobuf-4.25.2 sentencepiece-0.1.99
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install ipywidgets
# Out:
# Collecting ipywidgets
#   Downloading ipywidgets-8.1.2-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: comm>=0.1.3 in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from ipywidgets) (0.2.1)
# Requirement already satisfied: ipython>=6.1.0 in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from ipywidgets) (8.21.0)
# Requirement already satisfied: traitlets>=4.3.1 in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from ipywidgets) (5.14.1)
# Collecting widgetsnbextension~=4.0.10 (from ipywidgets)
#   Downloading widgetsnbextension-4.0.10-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab-widgets~=3.0.10 (from ipywidgets)
#   Downloading jupyterlab_widgets-3.0.10-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: decorator in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.1)
# Requirement already satisfied: matplotlib-inline in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.42)
# Requirement already satisfied: pygments>=2.4.0 in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.17.2)
# Requirement already satisfied: stack-data in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.2)
# Requirement already satisfied: exceptiongroup in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from ipython>=6.1.0->ipywidgets) (1.2.0)
# Requirement already satisfied: colorama in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: wcwidth in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.1)
# Requirement already satisfied: pure-eval in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: six>=1.12.0 in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)
# Downloading ipywidgets-8.1.2-py3-none-any.whl (139 kB)
#    ---------------------------------------- 0.0/139.4 kB ? eta -:--:--
#    -- ------------------------------------- 10.2/139.4 kB ? eta -:--:--
#    ----------- --------------------------- 41.0/139.4 kB 487.6 kB/s eta 0:00:01
#    --------------------------------- ---- 122.9/139.4 kB 901.1 kB/s eta 0:00:01
#    -------------------------------------- 139.4/139.4 kB 916.1 kB/s eta 0:00:00
# Downloading jupyterlab_widgets-3.0.10-py3-none-any.whl (215 kB)
#    ---------------------------------------- 0.0/215.0 kB ? eta -:--:--
#    ------------------------------- ------- 174.1/215.0 kB 10.9 MB/s eta 0:00:01
#    ---------------------------------------- 215.0/215.0 kB 3.3 MB/s eta 0:00:00
# Downloading widgetsnbextension-4.0.10-py3-none-any.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.2/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB 6.4 MB/s eta 0:00:01
#    ----------- ---------------------------- 0.7/2.3 MB 4.7 MB/s eta 0:00:01
#    ----------------- ---------------------- 1.0/2.3 MB 6.5 MB/s eta 0:00:01
#    ------------------------------ --------- 1.7/2.3 MB 7.9 MB/s eta 0:00:01
#    ---------------------------------------  2.3/2.3 MB 8.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 8.1 MB/s eta 0:00:00
# Installing collected packages: widgetsnbextension, jupyterlab-widgets, ipywidgets
# Successfully installed ipywidgets-8.1.2 jupyterlab-widgets-3.0.10 widgetsnbextension-4.0.10
# Note: you may need to restart the kernel to use updated packages.

# %%
# import the libaries

from datasets import load_dataset
from transformers import pipeline

# %%
# Creating a pipeline for the T5-small model and saving that into cache_dir

t5_small_pipeline = pipeline(
    task="text2text-generation",
    model="t5-small",
    max_length=50,
    model_kwargs={"cache_dir": '/Users/tarakram/Documents/Translate/t5_small' },
)
# Out:
# config.json: 100%|██████████| 1.21k/1.21k [00:00<?, ?B/s]
# d:\Vivek_Roushan\Task\Task1\LLM_HF\venvllmhf\lib\site-packages\huggingface_hub\file_download.py:149: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\promact\.cache\huggingface\hub\models--t5-small. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# config.json: 100%|██████████| 1.21k/1.21k [00:00<00:00, 1.21MB/s]
# d:\Vivek_Roushan\Task\Task1\LLM_HF\venvllmhf\lib\site-packages\huggingface_hub\file_download.py:149: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in D:\Users\tarakram\Documents\Translate\t5_small\models--t5-small. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# model.safetensors: 100%|██████████| 242M/242M [00:02<00:00, 81.2MB/s]
# generation_config.json: 100%|██████████| 147/147 [00:00<00:00, 249kB/s]
# tokenizer_config.json: 100%|██████████| 2.32k/2.32k [00:00<00:00, 2.32MB/s]
# spiece.model: 100%|██████████| 792k/792k [00:00<00:00, 978kB/s]
# tokenizer.json: 100%|██████████| 1.39M/1.39M [00:00<00:00, 38.5MB/s]

# %%
#  English to Romanian
# t5_small_pipeline(
#     "translate English to Romanian : Hey How are you ?"
# )

#English to Spanish

t5_small_pipeline(
    "translate English to Gujarati: Hey How are you ?"
)

# as we know that the model is not supported by many languages, it is limited to 
# few languages only
# Out:
# [{'generated_text': 'Hey How are you ?'}]

# %%
# %pip install openai
# Out:
# Collecting openai
#   Using cached openai-1.12.0-py3-none-any.whl.metadata (18 kB)
# Collecting anyio<5,>=3.5.0 (from openai)
#   Using cached anyio-4.2.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting distro<2,>=1.7.0 (from openai)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting httpx<1,>=0.23.0 (from openai)
#   Using cached httpx-0.26.0-py3-none-any.whl.metadata (7.6 kB)
# Collecting pydantic<3,>=1.9.0 (from openai)
#   Using cached pydantic-2.6.1-py3-none-any.whl.metadata (83 kB)
# Collecting sniffio (from openai)
#   Using cached sniffio-1.3.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: tqdm>4 in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from openai) (4.66.2)
# Requirement already satisfied: typing-extensions<5,>=4.7 in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from openai) (4.9.0)
# Requirement already satisfied: idna>=2.8 in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.6)
# Requirement already satisfied: exceptiongroup>=1.0.2 in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from anyio<5,>=3.5.0->openai) (1.2.0)
# Requirement already satisfied: certifi in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from httpx<1,>=0.23.0->openai) (2024.2.2)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai)
#   Downloading httpcore-1.0.3-py3-none-any.whl.metadata (20 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai)
#   Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Collecting annotated-types>=0.4.0 (from pydantic<3,>=1.9.0->openai)
#   Using cached annotated_types-0.6.0-py3-none-any.whl.metadata (12 kB)
# Collecting pydantic-core==2.16.2 (from pydantic<3,>=1.9.0->openai)
#   Using cached pydantic_core-2.16.2-cp310-none-win_amd64.whl.metadata (6.6 kB)
# Requirement already satisfied: colorama in d:\vivek_roushan\task\task1\llm_hf\venvllmhf\lib\site-packages (from tqdm>4->openai) (0.4.6)
# Using cached openai-1.12.0-py3-none-any.whl (226 kB)
# Using cached anyio-4.2.0-py3-none-any.whl (85 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached httpx-0.26.0-py3-none-any.whl (75 kB)
# Downloading httpcore-1.0.3-py3-none-any.whl (77 kB)
#    ---------------------------------------- 0.0/77.0 kB ? eta -:--:--
#    --------------- ------------------------ 30.7/77.0 kB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 77.0/77.0 kB 856.5 kB/s eta 0:00:00
# Using cached pydantic-2.6.1-py3-none-any.whl (394 kB)
# Using cached pydantic_core-2.16.2-cp310-none-win_amd64.whl (1.9 MB)
# Using cached annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Installing collected packages: sniffio, pydantic-core, h11, distro, annotated-types, pydantic, httpcore, anyio, httpx, openai
# Successfully installed annotated-types-0.6.0 anyio-4.2.0 distro-1.9.0 h11-0.14.0 httpcore-1.0.3 httpx-0.26.0 openai-1.12.0 pydantic-2.6.1 pydantic-core-2.16.2 sniffio-1.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# importing the libraries
import openai
# from .env import openapi_key
import os
# Enter your openAI Key here
# os.environ['OPENAI_API_KEY'] = openapi_key
OPENAI_API_KEY = "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"

# creating a function, that takes the text and asks the 
#source language and also the traget language

def translate_text(text, source_language, target_language):
    
    response = openai.Completion.create(
        engine='text-davinci-002',
        prompt=f"Translate the following text from {source_language} to {target_language}:\n{text}",
        max_tokens=100,
        n=1,
        stop=None,
        temperature=0.2,
        top_p=1.0,
        frequency_penalty=0.0,
        presence_penalty=0.0,
    )

    translation = response.choices[0].text.strip().split("\n")[0]
    return translation

# Get user input
text = input("Enter the text to translate: ")
source_language = input("Enter the source language: ")
target_language = input("Enter the target language: ")

translation = translate_text(text, source_language, target_language)

# print the translated text

print(f'Translated text: {translation}')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[13], line 3
#       1 # importing the libraries
#       2 import openai
# ----> 3 from .env import openapi_key
#       4 import os
#       5 # Enter your openAI Key here
#
# ImportError: attempted relative import with no known parent package
